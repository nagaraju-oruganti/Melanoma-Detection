# %%
import os
os.chdir('../src')

# %%
from config import Config
from trainer import train

config = Config()
config.data_dir = '../data'
config.models_dir = '../models'
config.show_folds_plot = False
config.model_name = 'baseline_convnet'
config.fold_dir = '../data/fold'
config.learning_rate = 1e-4
config.train_batch_size = 32
config.valid_batch_size = 128
config.num_epochs = 40
config.train_with_pre_resized_images = True
config.sample_run = False

config.model_arch_depth = [8, 16, 32]
config.dropout_map = [0] * len(config.model_arch_depth)
config.dropout_fc = []

config.fold = 4
_ = train(config = config)
